# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import time

# %%
template = "https://domicilios.com/restaurantes/bogota?isOnline=1&channels=pago-online&paymentMethods=112&bt=RESTAURANT&page={0}"
print(template.format(1))
print(template.format(1000))
# Out:
# https://domicilios.com/restaurantes/bogota?isOnline=1&channels=pago-online&paymentMethods=112&bt=RESTAURANT&page=1
# https://domicilios.com/restaurantes/bogota?isOnline=1&channels=pago-online&paymentMethods=112&bt=RESTAURANT&page=1000

# %%
rest_links = {}
driver = webdriver.Chrome(executable_path="./chromedriver")
i = 1
while True:
    driver.get(template.format(i))
    i += 1
    time.sleep(4)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    restaurantes = soup.find_all(class_="restaurantData")
    if len(restaurantes) < 10:
        break
    for res in restaurantes:
        name = res.find(class_="arrivalName").get_text()
        try:
            link = res.find("a", {"rel": "nofollow"})["href"]
        except:
            link = None
        rest_links[name] = link
driver.quit()

# %%
import pickle

with open("restaurantes_links.p", "wb") as f:
    pickle.dump(rest_links, f)

# %%
import pickle

with open("restaurantes_links.p", "rb") as f:
    dic = pickle.load(f)

# %%
dic
# Out:
# {'Pan Pa’ Ya! Cedritos 147': 'https://domicilios.com/restaurantes/bogota/pan-pa%E2%80%99-ya-cedritos-147-menu?t=comentarios',
#  'Pan Pa’ Ya! Chapinero': 'https://domicilios.com/restaurantes/bogota/pan-pa%E2%80%99-ya-chapinero-menu?t=comentarios',
#  "Pan Pa' Ya! Toberín": 'https://domicilios.com/restaurantes/bogota/pan-pa-ya-toberin-menu?t=comentarios',
#  'McDonalds NQS': 'https://domicilios.com/restaurantes/bogota/mcdonalds-nqs-menu?t=comentarios',
#  'McDonalds Usaquen': 'https://domicilios.com/restaurantes/bogota/mcdonalds-usaquen-menu?t=comentarios',
#  'McDonalds Cl 125': 'https://domicilios.com/restaurantes/bogota/mcdonalds-cl-125-menu?t=comentarios',
#  'KFC Calle 33': 'https://domicilios.com/restaurantes/bogota/kfc-calle-33-menu?t=comentarios',
#  'KFC Calle 85': 'https://domicilios.com/restaurantes/bogota/kfc-calle-85-menu?t=comentarios',
#  'McDonalds Suba': 'https://domicilios.com/restaurantes/bogota/mcdonalds-suba-menu?t=comentarios',
#  'McDonalds Calle 72': 'https://domicilios.com/restaurantes/bogota/mcdonalds-calle-72-menu?t=comentarios',
#  "Pan Pa' Ya! Home Center el Dorado": 'https://domicilios.com/restaurantes/bogota/pan-pa-ya-home-center-el-dorado-menu?t=comentarios',
#  'Pan Pa’ Ya! Pepe Sierra': 'https://domicilios.com/restaurantes/bogota/pan-pa%E2%80%99-ya-pepe-sierra-menu?t=comentarios',
#  'Oma Cedritos': 'https://domicilios.com/restaurantes/bogota/oma-cedritos-menu?t=comentarios',
#  'Subway Cedritos Calle 140': 'https://domicilios.com/restaurantes/bogota/subway-cedritos-calle-140-menu?t=comentarios',
#  'Pan Pa’ Ya! Mazuren 153': 'https://domicilios.com/restaurantes/bogota/pan-pa%E2%80%99-ya-mazuren-153-menu?t=comentarios',
#  'Lechoneria La Ricura Tolimense': 'https://domicilios.com/restaurantes/bogota/lechoneria-la-ricura-tolimense-menu?t=comentarios',
#  'La Frijolada 156': 'https://domicilios.com/restaurantes/bogota/la-frijolada-156-menu?t=comentarios',
#  'Juice Factory': 'https://domicilios.com/restaurantes/bogota/juice-factory-menu?t=comentarios',
#  'Pan Pa’ Ya! Salitre': 'https://domicilios.com/restaurantes/bogota/pan-pa%E2%80%99-ya-salitre-menu?t=comentarios',
#  "Pan Pa' Ya! Sarmiento": 'https://domicilios.com/restaurantes/bogota/pan-pa-ya-sarmiento-menu?t=comentarios',
#  'La Frijolada 107': 'https://domicilios.com/restaurantes/bogota/la-frijolada-107-menu?t=comentarios',
#  'Cosechas Calle 93': 'https://domicilios.com/restaurantes/bogota/cosechas-calle-93-menu?t=comentarios',
#  'Andrés Exprés - Pepe Sierra': 'https://domicilios.com/restaurantes/bogota/andres-expres-pepe-sierra-menu?t=comentarios',
#  'BÜN Burgers & Fries': 'https://domicilios.com/restaurantes/bogota/bun-burgers-fries-menu?t=comentarios',
#  'Pan Pa’ Ya! Calle 32': 'https://domicilios.com/restaurantes/bogota/pan-pa%E2%80%99-ya-calle-32-menu?t=comentarios',
#  'Pan Pa’ Ya! 127 Bella Suiza': 'https://domicilios.com/restaurantes/bogota/pan-pa%E2%80%99-ya-127-bella-suiza-menu?t=comentarios',
#  'El Portal de la Antigua': 'https://domicilios.com/restaurantes/bogota/el-portal-de-la-antigua-menu?t=comentarios',
#  'Frutería y Heladería Super Pattos #2': 'https://domicilios.com/restaurantes/bogota/fruteria-y-heladeria-super-pattos-2-menu?t=comentarios',
#  'Freshii Pepe Sierra': 'https://domicilios.com/restaurantes/bogota/freshii-pepe-sierra-menu?t=comentarios',
#  'Pan Pa’ Ya! Pasadena 100': 'https://domicilios.com/restaurantes/bogota/pan-pa%E2%80%99-ya-pasadena-100-menu?t=comentarios',
#  'Frutería y Heladería Súper Tropical': 'https://domicilios.com/restaurantes/bogota/fruteria-y-heladeria-super-tropical-menu?t=comentarios',
#  'Pan Pa’ Ya! Bulevar': 'https://domicilios.com/restaurantes/bogota/pan-pa%E2%80%99-ya-bulevar-menu?t=comentarios',
#  'Restaurante El Parque': 'https://domicilios.com/restaurantes/bogota/restaurante-el-parque-menu?t=comentarios',
#  'Casa Mexicana': 'https://domicilios.com/restaurantes/bogota/casa-mexicana-menu?t=comentarios',
#  "Pan Pa' Ya! CC Multiplaza": 'https://domicilios.com/restaurantes/bogota/pan-pa-ya-cc-multiplaza-menu?t=comentarios',
#  'Pan Pa’ Ya! La Calleja': 'https://domicilios.com/restaurantes/bogota/pan-pa%E2%80%99-ya-la-calleja-menu?t=comentarios',
#  'Lenteja Express Bogotá': 'https://domicilios.com/restaurantes/bogota/lenteja-express-bogota-menu?t=comentarios',
#  'Speed Desayunos Gourmet': 'https://domicilios.com/restaurantes/bogota/speed-desayunos-gourmet-menu?t=comentarios',
#  'La Plaza de Andrés Retiro': 'https://domicilios.com/restaurantes/bogota/la-plaza-de-andres-retiro-menu?t=comentarios',
#  'Rickys Pollo Y Parrilla': 'https://domicilios.com/restaurantes/bogota/rickys-pollo-y-parrilla-menu?t=comentarios',
#  'Pan Pa’ Ya! Rosales': 'https://domicilios.com/restaurantes/bogota/pan-pa%E2%80%99-ya-rosales-menu?t=comentarios',
#  'Pan Pa’ Ya! Paralela 106': 'https://domicilios.com/restaurantes/bogota/pan-pa%E2%80%99-ya-paralela-106-menu?t=comentarios',
#  'Subway Tintal': 'https://domicilios.com/restaurantes/bogota/subway-tintal-menu?t=comentarios',
#  'Pan Pa’ Ya! Batan': 'https://domicilios.com/restaurantes/bogota/pan-pa%E2%80%99-ya-batan-menu?t=comentarios',
#  'Pan Pa’ Ya! Colina 138': 'https://domicilios.com/restaurantes/bogota/pan-pa%E2%80%99-ya-colina-138-menu?t=comentarios',
#  'La Cesta 109': 'https://domicilios.com/restaurantes/bogota/la-cesta-109-menu?t=comentarios',
#  'Go Green Calle 95': 'https://domicilios.com/restaurantes/bogota/go-green-calle-95-menu?t=comentarios',
#  'Subway Galerias': 'https://domicilios.com/restaurantes/bogota/subway-galerias-menu?t=comentarios',
#  'Pan Pa’ Ya! Chico Miranda 103': 'https://domicilios.com/restaurantes/bogota/pan-pa%E2%80%99-ya-chico-miranda-103-menu?t=comentarios',
#  'La Frijolada 73': 'https://domicilios.com/restaurantes/bogota/la-frijolada-73-menu?t=comentarios',
#  'Cosechas Calle 147': 'https://domicilios.com/restaurantes/bogota/cosechas-calle-147-menu?t=comentarios',
#  'Desayunos del Norte': 'https://domicilios.com/restaurantes/bogota/desayunos-del-norte-menu?t=comentarios',
#  'Frutería Monkys Río Negro': 'https://domicilios.com/restaurantes/bogota/monkys-menu?t=comentarios',
#  'La Frijolada 32': 'https://domicilios.com/restaurantes/bogota/la-frijolada-32-menu?t=comentarios',
#  'La Plaza de Andrés Hacienda': 'https://domicilios.com/restaurantes/bogota/la-plaza-de-andres-hacienda-menu?t=comentarios',
#  'La Frute': 'https://domicilios.com/restaurantes/bogota/la-frute-menu?t=comentarios',
#  'Freshii Zona G': 'https://domicilios.com/restaurantes/bogota/freshii-zona-g-menu?t=comentarios',
#  'Subway Chicó 97': 'https://domicilios.com/restaurantes/bogota/subway-chico-97-menu?t=comentarios',
#  'Amor Infinito Cra 15': 'https://domicilios.com/restaurantes/bogota/amor-infinito-cra-15-menu?t=comentarios',
#  'Pan Pa’ Ya! Calle 90': 'https://domicilios.com/restaurantes/bogota/pan-pa%E2%80%99-ya-calle-90-menu?t=comentarios',
#  'Cosechas Calle 90': 'https://domicilios.com/restaurantes/bogota/cosechas-calle-90-menu?t=comentarios',
#  'Frutería y Heladería Sensación': 'https://domicilios.com/restaurantes/bogota/fruteria-y-heladeria-sensacion-menu?t=comentarios',
#  'Perniles de la Sabana Chapinero': 'https://domicilios.com/restaurantes/bogota/perniles-de-la-sabana-chapinero-menu?t=comentarios',
#  'Pan Pa’ Ya! Retiro 82': 'https://domicilios.com/restaurantes/bogota/pan-pa%E2%80%99-ya-retiro-82-menu?t=comentarios',
#  'De la Olla': 'https://domicilios.com/restaurantes/bogota/de-la-olla-menu?t=comentarios',
#  'Fit or Fat Shakes': 'https://domicilios.com/restaurantes/bogota/fit-or-fat-shakes-menu?t=comentarios',
#  'Freshii Teleport': 'https://domicilios.com/restaurantes/bogota/freshii-teleport-menu?t=comentarios',
#  'Subway Rosales 74': 'https://domicilios.com/restaurantes/bogota/subway-rosales-74-menu?t=comentarios',
#  'Donde Juancho Cra 104': 'https://domicilios.com/restaurantes/bogota/donde-juancho-cra-104-menu?t=comentarios',
#  'El Chócolo Calle 148': 'https://domicilios.com/restaurantes/bogota/el-chocolo-calle-148-menu?t=comentarios',
#  'El Chócolo Calle 85': 'https://domicilios.com/restaurantes/bogota/el-chocolo-calle-85-menu?t=comentarios',
#  'Fruteria Monkys Castellana': 'https://domicilios.com/restaurantes/bogota/fruteria-monkys-castellana-menu?t=comentarios',
#  'Los Kioscos': 'https://domicilios.com/restaurantes/bogota/los-kioscos-menu?t=comentarios',
#  'Restaurante Parrilla Come Mas': 'https://domicilios.com/restaurantes/bogota/restaurante-parrilla-come-mas-menu?t=comentarios',
#  'Subway Calle  85': 'https://domicilios.com/restaurantes/bogota/subway-calle-85-menu?t=comentarios',
#  'Empanadas Mi Tierrita': 'https://domicilios.com/restaurantes/bogota/empanadas-mi-tierrita-menu?t=comentarios',
#  'Cosechas 72': 'https://domicilios.com/restaurantes/bogota/cosechas-72-menu?t=comentarios',
#  'Fruterías Patty Av Chile': 'https://domicilios.com/restaurantes/bogota/fruterias-patty-av-chile-menu?t=comentarios',
#  'Subway Calle 90': 'https://domicilios.com/restaurantes/bogota/subway-calle-90-menu?t=comentarios',
#  'Freshii 93': 'https://domicilios.com/restaurantes/bogota/freshii-93-menu?t=comentarios',
#  'Frutiwow Bogotá': 'https://domicilios.com/restaurantes/bogota/frutiwow-bogota-menu?t=comentarios',
#  'Cosechas 125': 'https://domicilios.com/restaurantes/bogota/cosechas-125-menu?t=comentarios',
#  'El Chocolo - Av Chile': 'https://domicilios.com/restaurantes/bogota/el-chocolo-av-chile-menu?t=comentarios',
#  'Andrés Exprés - Calle 93': 'https://domicilios.com/restaurantes/bogota/andres-expres-calle-93-menu?t=comentarios',
#  'Yanuba Pastelería Cedritos': 'https://domicilios.com/restaurantes/bogota/yanuba-pasteleria-cedritos-menu?t=comentarios',
#  'Mamma Nunzia': 'https://domicilios.com/restaurantes/bogota/mamma-nunzia-menu?t=comentarios',
#  'Aliméntate Natural': 'https://domicilios.com/restaurantes/bogota/alimentate-natural-menu?t=comentarios',
#  'Yanuba 122': 'https://domicilios.com/restaurantes/bogota/yanuba-122-menu?t=comentarios',
#  'Cosechas Calle 100': 'https://domicilios.com/restaurantes/bogota/cosechas-calle-100-menu?t=comentarios',
#  'Cosechas Calle 38': 'https://domicilios.com/restaurantes/bogota/cosechas-calle-38-menu?t=comentarios',
#  'Raíces Bienestar Gourmet bogotá': 'https://domicilios.com/restaurantes/bogota/raices-bienestar-gourmet-bogota-menu?t=comentarios',
#  'Greenomy': 'https://domicilios.com/restaurantes/bogota/greenomy-menu?t=comentarios',
#  'Hamburguesas El Corral Calle 90': 'https://domicilios.com/restaurantes/bogota/hamburguesas-el-corral-calle-90-menu?t=comentarios',
#  'Pan Pa’ Ya! Calle 96': 'https://domicilios.com/restaurantes/bogota/pan-pa%E2%80%99-ya-calle-96-menu?t=comentarios',
#  'Rapicadas y Licores': 'https://domicilios.com/restaurantes/bogota/rapicadas-y-licores-menu?t=comentarios',
#  'Subway Calle 145': 'https://domicilios.com/restaurantes/bogota/subway-calle-145-menu?t=comentarios',
#  'Farandula Parrilla': 'https://domicilios.com/restaurantes/bogota/farandula-parrilla-menu?t=comentarios',
#  'Capital Bagels Chicó': 'https://domicilios.com/restaurantes/bogota/capital-bagels-chico-menu?t=comentarios',
#  'Pan Pa’ Ya! Unicentro': 'https://domicilios.com/restaurantes/bogota/pan-pa%E2%80%99-ya-unicentro-menu?t=comentarios',
#  'FreshCo Bogotá': 'https://domicilios.com/restaurantes/bogota/freshco-bogota-menu?t=comentarios',
#  'Choricarnes y Costilla': 'https://domicilios.com/restaurantes/bogota/choricarnes-y-costilla-menu?t=comentarios',
#  'Asian Wok Buffet': 'https://domicilios.com/restaurantes/bogota/asian-wok-buffet-menu?t=comentarios',
#  'Cosechas Quinta Camacho': 'https://domicilios.com/restaurantes/bogota/cosechas-quinta-camacho-menu?t=comentarios',
#  'Yanuba Cedritos': 'https://domicilios.com/restaurantes/bogota/yanuba-cedritos-menu?t=comentarios',
#  'La Sabana': 'https://domicilios.com/restaurantes/bogota/la-sabana-menu?t=comentarios',
#  'Yanuba Pastelería Cll 122': 'https://domicilios.com/restaurantes/bogota/yanuba-pasteleria-cll-122-menu?t=comentarios',
#  "Arep'art": 'https://domicilios.com/restaurantes/bogota/arep-art-menu?t=comentarios',
#  'Ana Rebana Calle 71': 'https://domicilios.com/restaurantes/bogota/ana-rebana-calle-93-menu?t=comentarios',
#  'Lechonería La Ricura Tolimense MP': 'https://domicilios.com/restaurantes/bogota/lechoneria-la-ricura-tolimense-mp-menu?t=comentarios',
#  'Distrito Gourmet': 'https://domicilios.com/restaurantes/bogota/distrito-gourmet-menu?t=comentarios',
#  'Paella Burquet': 'https://domicilios.com/restaurantes/bogota/paella-burquet-menu?t=comentarios',
#  'Cosechas 116': 'https://domicilios.com/restaurantes/bogota/cosechas-116-menu?t=comentarios',
#  'Tienda Prestige': 'https://domicilios.com/restaurantes/bogota/tienda-prestige-menu?t=comentarios',
#  'Naguará De Arepas Calle 147': 'https://domicilios.com/restaurantes/bogota/naguara-de-arepas-calle-147-menu?t=comentarios',
#  '9am Desayuno': 'https://domicilios.com/restaurantes/bogota/9am-desayuno-menu?t=comentarios',
#  'Restaurante Zan Chin': 'https://domicilios.com/restaurantes/bogota/restaurante-zan-chin-menu?t=comentarios',
#  'Ana Rebana Calle 99': 'https://domicilios.com/restaurantes/bogota/ana-rebana-menu?t=comentarios',
#  'Darlyng Ice Cream': 'https://domicilios.com/restaurantes/bogota/darlyng-ice-cream-menu?t=comentarios',
#  'Cosechas Santa Barbara': 'https://domicilios.com/restaurantes/bogota/cosechas-santa-barbara-menu?t=comentarios',
#  'Arroz Paisa Sabor Caldense LOG': 'https://domicilios.com/restaurantes/bogota/arroz-paisa-sabor-caldense-log-menu?t=comentarios',
#  'Hamburguesas El Corral El Lago Calle 76': 'https://domicilios.com/restaurantes/bogota/hamburguesas-el-corral-el-lago-calle-76-menu?t=comentarios',
#  'Santa Chona': 'https://domicilios.com/restaurantes/bogota/santa-chona-menu?t=comentarios',
#  'Andrés Exprés - Andes': 'https://domicilios.com/restaurantes/bogota/andres-expres-andes-menu?t=comentarios',
#  'Pan Pa’ Ya! Chico 95': 'https://domicilios.com/restaurantes/bogota/pan-pa%E2%80%99-ya-chico-95-menu?t=comentarios',
#  'La Seniora Pastelería': 'https://domicilios.com/restaurantes/bogota/la-seniora-pasteleria-menu?t=comentarios',
#  'Freshii Andino': 'https://domicilios.com/restaurantes/bogota/freshii-andino-menu?t=comentarios',
#  'Café Dulce': 'https://domicilios.com/restaurantes/bogota/cafe-dulce-menu?t=comentarios',
#  'Calentao To Go': 'https://domicilios.com/restaurantes/bogota/calentao-to-go-menu?t=comentarios',
#  'Deli Repostería Contador': 'https://domicilios.com/restaurantes/bogota/deli-reposteria-contador-menu?t=comentarios',
#  'Ricuras de la 62': None,
#  'Típicas Empanadas Cafam Floresta': 'https://domicilios.com/restaurantes/bogota/tipicas-empanadas-floresta-menu?t=comentarios',
#  'Mi Patria': 'https://domicilios.com/restaurantes/bogota/mi-patria-menu?t=comentarios',
#  'Deli Repostería Andino': 'https://domicilios.com/restaurantes/bogota/deli-reposteria-andino-menu?t=comentarios',
#  'El Gourmet de los Arroces, Pastas y Cazuelas': 'https://domicilios.com/restaurantes/bogota/el-gourmet-de-los-arroces-pastas-y-cazuelas-menu?t=comentarios',
#  'Desayunos y Algo Más': 'https://domicilios.com/restaurantes/bogota/desayunos-y-algo-mas-menu?t=comentarios',
#  'Canaima Usaquén': 'https://domicilios.com/restaurantes/bogota/criollo-s-usaquen-menu?t=comentarios',
#  'Deli Repostería Santa Barbara Drive': 'https://domicilios.com/restaurantes/bogota/deli-reposteria-santa-barbara-drive-menu?t=comentarios',
#  'El Truck de Omar': 'https://domicilios.com/restaurantes/bogota/el-truck-de-omar-menu?t=comentarios',
#  'Pan Pa’ Ya! Calle 85': 'https://domicilios.com/restaurantes/bogota/pan-pa%E2%80%99-ya-calle-85-menu?t=comentarios',
#  'Frutos del Bosque Zona Franca': 'https://domicilios.com/restaurantes/bogota/frutos-del-bosque-zona-franca-menu?t=comentarios',
#  'Arepas Café CC Niza': 'https://domicilios.com/restaurantes/bogota/arepas-cafe-cc-niza-menu?t=comentarios',
#  'Gula Gourmet Cll 69': 'https://domicilios.com/restaurantes/bogota/gula-gourmet-cll-69-menu?t=comentarios',
#  'Gula Gourmet Cr 106': 'https://domicilios.com/restaurantes/bogota/gula-gourmet-cr-106-menu?t=comentarios',
#  'Pan Pa’ Ya! Centro': 'https://domicilios.com/restaurantes/bogota/pan-pa%E2%80%99-ya-centro-menu?t=comentarios',
#  'Sabrosuras Costeñas': 'https://domicilios.com/restaurantes/bogota/sabrosuras-costenas-menu?t=comentarios',
#  'Merkapan Expresso': 'https://domicilios.com/restaurantes/bogota/merkapan-expresso-menu?t=comentarios',
#  'Pasta y Pizza': 'https://domicilios.com/restaurantes/bogota/pasta-y-pizza-menu?t=comentarios',
#  'Rebeca': 'https://domicilios.com/restaurantes/bogota/rebeca-menu?t=comentarios',
#  'Tequecool': 'https://domicilios.com/restaurantes/bogota/tequecool-menu?t=comentarios',
#  'Arepas Café Calle 98': 'https://domicilios.com/restaurantes/bogota/arepas-cafe-calle-98-menu?t=comentarios',
#  'Batimix  Teusaquillo': 'https://domicilios.com/restaurantes/bogota/batimix-teusaquillo-menu?t=comentarios',
#  'Nicolukas Pastelería': 'https://domicilios.com/restaurantes/bogota/nicolukas-pasteleria-menu?t=comentarios',
#  'Yoli Fogón': 'https://domicilios.com/restaurantes/bogota/yoli-fogon-menu?t=comentarios',
#  'Tamales Ricos': 'https://domicilios.com/restaurantes/bogota/tamales-ricos-menu?t=comentarios',
#  'Speed Broaster El Prado': 'https://domicilios.com/restaurantes/bogota/speed-broaster-cobertura-pequena-menu?t=comentarios',
#  'Super Fruti': 'https://domicilios.com/restaurantes/bogota/super-fruti-menu?t=comentarios',
#  'La Barra Cevichería': 'https://domicilios.com/restaurantes/bogota/la-barra-cevicheria-menu?t=comentarios',
#  'Bio Hari': None,
#  'Buffet Chef Life': None,
#  'Canela Delicias Veganas Galerías': None,
#  'Cocina Restaurante': None,
#  'Cosechas CC Plaza Shopping': None,
#  'Cosechas Home Center 180': None,
#  'Cosechas Portal Norte': None,
#  'Cosechas Victoria Norte': None,
#  'Delicias de Mamá': None,
#  'El Chocolo - Calle 136': None,
#  'El Chócolo': None,
#  'El Chócolo 97': None,
#  'El Chócolo Calle 140': None,
#  'El Chócolo calle 170': None,
#  'El Jefazo Comida Rapida': None,
#  'Entre Frutas & Café': None,
#  'God Bless Colombia Arepas': None,
#  'Nativos Pepe Sierra': None,
#  'Niko Sazón': None,
#  'Paladar Gourmet': None,
#  'Pig Queen Exito Suba': None,
#  'Pizza Green': None,
#  'Tapas y Kbas': None,
#  'Tántalo': None,
#  'Señor Jamonero': 'https://domicilios.com/restaurantes/bogota/senor-jamonero-menu?t=comentarios',
#  'Nicolukas': 'https://domicilios.com/restaurantes/bogota/nicolukas-menu?t=comentarios',
#  'Panela Haus': 'https://domicilios.com/restaurantes/bogota/panela-haus-menu?t=comentarios',
#  'La Parrilla Dorada Polo': 'https://domicilios.com/restaurantes/bogota/la-parrilla-dorada-polo-menu?t=comentarios',
#  'Pan Pa’ Ya! Nogal 76': 'https://domicilios.com/restaurantes/bogota/pan-pa%E2%80%99-ya-nogal-76-menu?t=comentarios',
#  "RapiSnack's": 'https://domicilios.com/restaurantes/bogota/rapisnack%C2%B4s-menu?t=comentarios',
#  'Levelma Colina': 'https://domicilios.com/restaurantes/bogota/levelma-colina-menu?t=comentarios',
#  'Tu Casa Restaurante': 'https://domicilios.com/restaurantes/bogota/tu-casa-restaurante-menu?t=comentarios',
#  'Como En Casa Modelia': 'https://domicilios.com/restaurantes/bogota/como-en-casa-modelia-menu?t=comentarios',
#  'Bokata Bogotá': 'https://domicilios.com/restaurantes/bogota/bokata-bogota-menu?t=comentarios',
#  'Prema': 'https://domicilios.com/restaurantes/bogota/prema-menu?t=comentarios',
#  'Deli Repostería Chico Calle 90': 'https://domicilios.com/restaurantes/bogota/deli-reposteria-chico-calle-90-menu?t=comentarios',
#  'Levelma Calle 170': 'https://domicilios.com/restaurantes/bogota/levelma-calle-170-menu?t=comentarios',
#  'La Frute Caobos': None,
#  'Triangular Café': None,
#  'Figaro Café Argentino': None,
#  'Pecaminosas Torre Central Davivienda': None,
#  'Sano y Salvo': None,
#  'Swing Sandwich 71': None,
#  'Mays': 'https://domicilios.com/restaurantes/bogota/mays-menu?t=comentarios',
#  'Hamburguesas Santa Fé Marketplace Centro': 'https://domicilios.com/restaurantes/bogota/hamburguesas-santa-fe-marketplace-centro-menu?t=comentarios',
#  'Frutería Wimpys Quirigua': 'https://domicilios.com/restaurantes/bogota/wimpy-s-menu?t=comentarios',
#  'Fressco': None,
#  'Pecaminosas Santa Barbara Bogotá': None,
#  'Dolci Cornetti Pasticceria Italiana': None,
#  'Deli Repostería Cedritos': None,
#  'Cazuelitas Gourmet': None,
#  'Tamales a Domicilio.com': 'https://domicilios.com/restaurantes/bogota/tamales-a-domiciliocom-menu?t=comentarios',
#  'Speed Chicken Bogota Cll 145': None,
#  'Speed Chicken Cr 70': None,
#  'El Automático Burger Bistró': None,
#  'Speed Broaster Carrera 70': None,
#  'Levelma Rosales': 'https://domicilios.com/restaurantes/bogota/levelma-rosales-menu?t=comentarios',
#  'Bukowski Bar & Bistro': None,
#  'Deli Repostería Cedritos Plaza': None,
#  'Pan Pa’ Ya! Centro Internacional': None,
#  'Subway Villa del Prado': 'https://domicilios.com/restaurantes/bogota/subway-villa-del-prado-menu?t=comentarios',
#  'Levelma Santa Fé': None,
#  'Desayunos y Onces Sorpresas': None,
#  'Subway Colpatria': None,
#  'Titanium': None,
#  'FrutyBurger': None,
#  'Restaurante La Victoria': None,
#  'Subway Santafe': 'https://domicilios.com/restaurantes/bogota/subway-santafe-menu?t=comentarios',
#  'Pan Pa’ Ya! World Trade Center': None,
#  'Pan Pa’ Ya! Calle 98': None,
#  'Buñuelos Nacho': None,
#  'Presto Cedritos': 'https://domicilios.com/restaurantes/bogota/presto-cedritos-menu?t=comentarios',
#  'Mister Lee Calle 127': 'https://domicilios.com/restaurantes/bogota/mister-lee-calle-127-menu?t=comentarios',
#  'Presto Colina Campestre': 'https://domicilios.com/restaurantes/bogota/presto-colina-campestre-menu?t=comentarios',
#  'Hamburguesas del Rodeo Americas': 'https://domicilios.com/restaurantes/bogota/hamburguesas-del-rodeo-americas-menu?t=comentarios',
#  'Presto Galerias': 'https://domicilios.com/restaurantes/bogota/presto-galerias-menu?t=comentarios',
#  'Presto Santa Isabel': 'https://domicilios.com/restaurantes/bogota/presto-santa-isabel-menu?t=comentarios',
#  'Sr Wok Javeriana': 'https://domicilios.com/restaurantes/bogota/sr-wok-javeriana-menu?t=comentarios',
#  'Sr Wok C.C Hacienda Santa Barbara': 'https://domicilios.com/restaurantes/bogota/sr-wok-c-c-hacienda-santa-barbara-menu?t=comentarios',
#  'Mister Lee Hacienda Santa Bárbara': 'https://domicilios.com/restaurantes/bogota/mister-lee-hacienda-santa-barbara-menu?t=comentarios',
#  'Hamburguesas del Rodeo Calle 70 con 11': 'https://domicilios.com/restaurantes/bogota/hamburguesas-del-rodeo-calle-70-con-11-menu?t=comentarios',
#  'Presto Tintal Plaza': 'https://domicilios.com/restaurantes/bogota/presto-tintal-plaza-menu?t=comentarios',
#  'Presto Normandia': 'https://domicilios.com/restaurantes/bogota/presto-normandia-menu?t=comentarios',
#  'Sr Wok Santa Fe': 'https://domicilios.com/restaurantes/bogota/sr-wok-santa-fe-menu?t=comentarios',
#  'Presto Modelia': 'https://domicilios.com/restaurantes/bogota/presto-modelia-menu?t=comentarios',
#  'KFC CC Plaza Imperial': 'https://domicilios.com/restaurantes/bogota/kfc-cc-plaza-imperial-menu?t=comentarios',
#  'Presto Javeriana': 'https://domicilios.com/restaurantes/bogota/presto-javeriana-menu?t=comentarios',
#  'Presto Calle 85': 'https://domicilios.com/restaurantes/bogota/presto-calle-85-menu?t=comentarios',
#  'Presto Portal 80': 'https://domicilios.com/restaurantes/bogota/presto-portal-80-menu?t=comentarios',
#  'Presto Plaza Imperial': 'https://domicilios.com/restaurantes/bogota/presto-plaza-imperial-menu?t=comentarios',
#  'Sr Wok Tintal': 'https://domicilios.com/restaurantes/bogota/sr-wok-tintal-menu?t=comentarios',
#  'Presto Jumbo  Calle 80': 'https://domicilios.com/restaurantes/bogota/presto-jumbo-calle-80-menu?t=comentarios',
#  'Presto Calle 100': 'https://domicilios.com/restaurantes/bogota/presto-calle-100-menu?t=comentarios',
#  'Presto Salitre Plaza': 'https://domicilios.com/restaurantes/bogota/presto-salitre-plaza-menu?t=comentarios',
#  'Presto Plaza de las Americas': 'https://domicilios.com/restaurantes/bogota/presto-calle-plaza-menu?t=comentarios',
#  'PPC Chapinero': 'https://domicilios.com/restaurantes/bogota/ppc-chapinero-menu?t=comentarios',
#  'Hamburguesas del Rodeo 170': 'https://domicilios.com/restaurantes/bogota/hamburguesas-del-rodeo-170-menu?t=comentarios',
#  'Charlies Roastbeef Av 15': 'https://domicilios.com/restaurantes/bogota/charlies-roastbeef-av-15-7717-menu?t=comentarios',
#  'Presto Home Center 170': 'https://domicilios.com/restaurantes/bogota/presto-home-center-170-menu?t=comentarios',
#  'Hamburguesas del Rodeo Boyaca': 'https://domicilios.com/restaurantes/bogota/hamburguesas-del-rodeo-boyaca-menu?t=comentarios',
#  'Hamburguesas del Rodeo Cra 30': 'https://domicilios.com/restaurantes/bogota/hamburguesas-del-rodeo-cra-30-menu?t=comentarios',
#  'Hamburguesas del Rodeo Fontibón': 'https://domicilios.com/restaurantes/bogota/hamburguesas-del-rodeo-fontibon-menu?t=comentarios',
#  'Hamburguesas del Rodeo Palatino': 'https://domicilios.com/restaurantes/bogota/hamburguesas-del-rodeo-palatino-menu?t=comentarios',
#  'PPC Suba Gaitana': 'https://domicilios.com/restaurantes/bogota/ppc-suba-gaitana-menu?t=comentarios',
#  'Sr Wok Floresta': 'https://domicilios.com/restaurantes/bogota/sr-wok-floresta-menu?t=comentarios',
#  'El Carnal Cedritos': 'https://domicilios.com/restaurantes/bogota/el-carnal-cedritos-menu?t=comentarios',
#  'KFC Santafé Bogotá': 'https://domicilios.com/restaurantes/bogota/kfc-santafe-bogota-menu?t=comentarios',
#  'Cali Vea Cedritos': 'https://domicilios.com/restaurantes/bogota/cali-vea-cedritos-menu?t=comentarios',
#  'Sr Wok Colina': 'https://domicilios.com/restaurantes/bogota/sr-wok-colina-menu?t=comentarios',
#  'Presto Chapinero': 'https://domicilios.com/restaurantes/bogota/presto-chapinero-menu?t=comentarios',
#  'Sr Wok Portal de la 80': 'https://domicilios.com/restaurantes/bogota/sr-wok-portal-de-la-80-menu?t=comentarios',
#  'Presto Jumbo 170': 'https://domicilios.com/restaurantes/bogota/presto-jumbo-170-menu?t=comentarios',
#  'Presto Calle 23': 'https://domicilios.com/restaurantes/bogota/presto-calle-23-menu?t=comentarios',
#  'Hamburguesas del Rodeo C.C. 80': 'https://domicilios.com/restaurantes/bogota/hamburguesas-del-rodeo-c-c-80-menu?t=comentarios',
#  'Cali Vea Castilla': 'https://domicilios.com/restaurantes/bogota/cali-vea-castilla-menu?t=comentarios',
#  'Cali Vea Lourdes': 'https://domicilios.com/restaurantes/bogota/cali-vea-lourdes-menu?t=comentarios',
#  'KFC CC Bulevar': 'https://domicilios.com/restaurantes/bogota/kfc-cc-bulevar-menu?t=comentarios',
#  'Presto Esmeralda': 'https://domicilios.com/restaurantes/bogota/presto-esmeralda-menu?t=comentarios',
#  'McDonalds Colina': 'https://domicilios.com/restaurantes/bogota/mcdonalds-colina-menu?t=comentarios',
#  'Charlies Roastbeef Calle 72': 'https://domicilios.com/restaurantes/bogota/charlies-roastbeef-calle-72-menu?t=comentarios',
#  'Sr Wok Plaza Central': 'https://domicilios.com/restaurantes/bogota/sr-wok-plaza-central-menu?t=comentarios',
#  'Kokoriko Central Domicilios Usaquen': 'https://domicilios.com/restaurantes/bogota/kokoriko-central-domicilios-usaquen-menu?t=comentarios',
#  'Presto Calle 74': 'https://domicilios.com/restaurantes/bogota/presto-calle-74-menu?t=comentarios',
#  'KFC Cedritos': 'https://domicilios.com/restaurantes/bogota/kfc-cedritos-menu?t=comentarios',
#  'PPC Colina': 'https://domicilios.com/restaurantes/bogota/ppc-colina-menu?t=comentarios',
#  'Presto Exito Occidente': 'https://domicilios.com/restaurantes/bogota/presto-exito-occidente-menu?t=comentarios',
#  'Hamburguesas del Rodeo Plaza Imperial': 'https://domicilios.com/restaurantes/bogota/hamburguesas-del-rodeo-plaza-imperial-menu?t=comentarios',
#  'Hamburguesas del Rodeo 127': 'https://domicilios.com/restaurantes/bogota/hamburguesas-del-rodeo-127-menu?t=comentarios',
#  'Presto Home Center 80': 'https://domicilios.com/restaurantes/bogota/presto-home-center-80-menu?t=comentarios',
#  'Poked  - Usaquén': 'https://domicilios.com/restaurantes/bogota/poked-bogota-menu?t=comentarios',
#  'Cali Vea Colina Campestre': 'https://domicilios.com/restaurantes/bogota/cali-vea-colina-campestre-menu?t=comentarios',
#  'Sr Wok Gran Estación': 'https://domicilios.com/restaurantes/bogota/sr-wok-gran-estacion-menu?t=comentarios',
#  'Presto Jumbo Autopista Sur': 'https://domicilios.com/restaurantes/bogota/presto-jumbo-autopista-sur-menu?t=comentarios',
#  'KFC Centro Comercial Portal 80': 'https://domicilios.com/restaurantes/bogota/kfc-centro-comercial-portal-80-menu?t=comentarios',
#  'Presto Diver Plaza': 'https://domicilios.com/restaurantes/bogota/presto-diver-plaza-menu?t=comentarios',
#  'PPC Cedritos': 'https://domicilios.com/restaurantes/bogota/ppc-cedritos-menu?t=comentarios',
#  'Cali Vea Galerias': 'https://domicilios.com/restaurantes/bogota/cali-vea-galerias-menu?t=comentarios',
#  'Hamburguesas del Rodeo Salitre': 'https://domicilios.com/restaurantes/bogota/hamburguesas-del-rodeo-salitre-menu?t=comentarios',
#  'PPC Villa del Prado': 'https://domicilios.com/restaurantes/bogota/ppc-villa-del-prado-menu?t=comentarios',
#  'Presto Iserra 100': 'https://domicilios.com/restaurantes/bogota/presto-iserra-100-menu?t=comentarios',
#  'Hamburguesas del Rodeo Alamos': 'https://domicilios.com/restaurantes/bogota/hamburguesas-del-rodeo-alamos-menu?t=comentarios',
#  'Arroz Paisa Suba': 'https://domicilios.com/restaurantes/bogota/arroz-paisa-suba-menu?t=comentarios',
#  'Charlies Roastbeef Pasadena': 'https://domicilios.com/restaurantes/bogota/charlies-roastbeef-pasadena-7718-menu?t=comentarios',
#  'Hamburguesas del Rodeo Suba': 'https://domicilios.com/restaurantes/bogota/hamburguesas-del-rodeo-suba-menu?t=comentarios',
#  'Kokoriko Parque 43': 'https://domicilios.com/restaurantes/bogota/kokoriko-parque-43-menu?t=comentarios',
#  'KFC Shaio': 'https://domicilios.com/restaurantes/bogota/kfc-shaio-menu?t=comentarios',
#  'Presto Villa del Prado': 'https://domicilios.com/restaurantes/bogota/presto-villa-del-prado-menu?t=comentarios',
#  'Kokoriko Fontibón': 'https://domicilios.com/restaurantes/bogota/kokoriko-fontibon-menu?t=comentarios',
#  'Kokoriko Calle 125': 'https://domicilios.com/restaurantes/bogota/kokoriko-calle-125-menu?t=comentarios',
#  'Cali Vea Ilarco': 'https://domicilios.com/restaurantes/bogota/cali-vea-ilarco-menu?t=comentarios',
#  "Noah's Green Kitchen - Cedritos": 'https://domicilios.com/restaurantes/bogota/noah-s-menu?t=comentarios',
#  'KFC Parkway': 'https://domicilios.com/restaurantes/bogota/kfc-parkway-menu?t=comentarios',
#  'Presto Centenario': 'https://domicilios.com/restaurantes/bogota/presto-centenario-menu?t=comentarios',
#  'Presto Éxito Country': 'https://domicilios.com/restaurantes/bogota/presto-exito-country-menu?t=comentarios',
#  'Hamburguesas del Rodeo Colpatria': 'https://domicilios.com/restaurantes/bogota/hamburguesas-del-rodeo-colpatria-menu?t=comentarios',
#  'Mister Lee Calima': 'https://domicilios.com/restaurantes/bogota/mister-lee-calima-menu?t=comentarios',
#  'Kokoriko Galerias': 'https://domicilios.com/restaurantes/bogota/kokoriko-galerias-menu?t=comentarios',
#  'Cali Vea Contador': 'https://domicilios.com/restaurantes/bogota/cali-vea-contador-menu?t=comentarios',
#  'Cali Vea Chapinero Calle 41': 'https://domicilios.com/restaurantes/bogota/cali-vea-chapinero-calle-41-menu?t=comentarios',
#  'Cali Vea Cipres': 'https://domicilios.com/restaurantes/bogota/cali-vea-cipres-menu?t=comentarios',
#  'MUY Calle 57': 'https://domicilios.com/restaurantes/bogota/muy-calle-57-menu?t=comentarios',
#  'La Brasa Roja Pepe Sierra': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-pepe-sierra-menu?t=comentarios',
#  'Presto Morato': 'https://domicilios.com/restaurantes/bogota/presto-morato-menu?t=comentarios',
#  'Cali Vea Garcés Navas': 'https://domicilios.com/restaurantes/bogota/cali-vea-garces-navas-menu?t=comentarios',
#  'Presto San Rafael': 'https://domicilios.com/restaurantes/bogota/presto-san-rafael-menu?t=comentarios',
#  'Presto Exito Fontibon': 'https://domicilios.com/restaurantes/bogota/presto-exito-fontibon-menu?t=comentarios',
#  'Sr Wok Andino': 'https://domicilios.com/restaurantes/bogota/sr-wok-andino-menu?t=comentarios',
#  'PPC Fontibon': 'https://domicilios.com/restaurantes/bogota/ppc-fontibon-menu?t=comentarios',
#  'La Brasa Roja Ilarco': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-ilarco-menu?t=comentarios',
#  'Sr Wok San Martin': 'https://domicilios.com/restaurantes/bogota/sr-wok-san-martin-menu?t=comentarios',
#  'Cali Vea Castellana': 'https://domicilios.com/restaurantes/bogota/cali-vea-castellana-menu?t=comentarios',
#  'Cali Vea Margaritas': 'https://domicilios.com/restaurantes/bogota/cali-vea-margaritas-menu?t=comentarios',
#  'Presto Bahia Bogotá': 'https://domicilios.com/restaurantes/bogota/presto-bahia-bogota-menu?t=comentarios',
#  'KFC Ferias': 'https://domicilios.com/restaurantes/bogota/kfc-ferias-menu?t=comentarios',
#  'Hamburguesas del Rodeo Castellana': 'https://domicilios.com/restaurantes/bogota/hamburguesas-del-rodeo-castellana-menu?t=comentarios',
#  'PPC Bosa': 'https://domicilios.com/restaurantes/bogota/ppc-bosa-menu?t=comentarios',
#  'McDonalds Galerias': 'https://domicilios.com/restaurantes/bogota/mcdonalds-galerias-menu?t=comentarios',
#  'Cali Vea Pepe Sierra': 'https://domicilios.com/restaurantes/bogota/cali-vea-pepe-sierra-menu?t=comentarios',
#  'McDonalds Floresta': 'https://domicilios.com/restaurantes/bogota/mcdonalds-floresta-menu?t=comentarios',
#  'PPC Estrada': 'https://domicilios.com/restaurantes/bogota/ppc-estrada-menu?t=comentarios',
#  'PPC Venecia': 'https://domicilios.com/restaurantes/bogota/ppc-venecia-menu?t=comentarios',
#  'Sr Wok C.C Plaza de las Americas': 'https://domicilios.com/restaurantes/bogota/sr-wok-c-c-plaza-de-las-americas-menu?t=comentarios',
#  'Kokoriko Salitre Plaza': 'https://domicilios.com/restaurantes/bogota/kokoriko-salitre-plaza-menu?t=comentarios',
#  'Cali Vea Home Center Tintal': 'https://domicilios.com/restaurantes/bogota/cali-vea-home-center-tintal-menu?t=comentarios',
#  'La Brasa Roja Alkosto 170': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-alkosto-170-menu?t=comentarios',
#  'Presto Kennedy': 'https://domicilios.com/restaurantes/bogota/presto-kennedy-menu?t=comentarios',
#  'Hamburguesas del Rodeo Centro': 'https://domicilios.com/restaurantes/bogota/hamburguesas-del-rodeo-centro-menu?t=comentarios',
#  'Cali Vea Normandia': 'https://domicilios.com/restaurantes/bogota/cali-vea-normandia-menu?t=comentarios',
#  'Kokoriko Villa Alsacia': 'https://domicilios.com/restaurantes/bogota/kokoriko-villa-alsacia-menu?t=comentarios',
#  'Sr Wok Centro Mayor': 'https://domicilios.com/restaurantes/bogota/sr-wok-centro-mayor-menu?t=comentarios',
#  'Cali Vea Auto Norte': 'https://domicilios.com/restaurantes/bogota/cali-vea-auto-norte-menu?t=comentarios',
#  'Cali Vea Quirigua': 'https://domicilios.com/restaurantes/bogota/cali-vea-quirigua-menu?t=comentarios',
#  'Presto Hacienda Santa Barbara': 'https://domicilios.com/restaurantes/bogota/presto-hacienda-santa-barbara-menu?t=comentarios',
#  'Kokoriko CC Calle 184': 'https://domicilios.com/restaurantes/bogota/kokoriko-cc-calle-184-menu?t=comentarios',
#  'Kokoriko Home Center CLL 80': 'https://domicilios.com/restaurantes/bogota/kokoriko-home-center-cll-80-menu?t=comentarios',
#  'PPC Hayuelos': 'https://domicilios.com/restaurantes/bogota/ppc-hayuelos-menu?t=comentarios',
#  'Cali Vea CC Cedritos': 'https://domicilios.com/restaurantes/bogota/cali-vea-cc-cedritos-menu?t=comentarios',
#  'Kokoriko  Villas': 'https://domicilios.com/restaurantes/bogota/kokoriko-villas-menu?t=comentarios',
#  'Cali Vea World Trade Center': 'https://domicilios.com/restaurantes/bogota/cali-vea-world-trade-center-menu?t=comentarios',
#  'Presto Av. 68': 'https://domicilios.com/restaurantes/bogota/presto-av-68-menu?t=comentarios',
#  'PPC Suba': 'https://domicilios.com/restaurantes/bogota/ppc-suba-menu?t=comentarios',
#  'Mister Lee Jumbo Cra 30': 'https://domicilios.com/restaurantes/bogota/mister-lee-jumbo-cra-30-menu?t=comentarios',
#  'Kokoriko San Diego': 'https://domicilios.com/restaurantes/bogota/kokoriko-san-diego-menu?t=comentarios',
#  'Cali Vea Santa Isabel': 'https://domicilios.com/restaurantes/bogota/cali-vea-santa-isabel-menu?t=comentarios',
#  'PPC Restrepo': 'https://domicilios.com/restaurantes/bogota/ppc-restrepo-menu?t=comentarios',
#  'Charlies Roastbeef Palatino': 'https://domicilios.com/restaurantes/bogota/charlies-roastbeef-palatino-menu?t=comentarios',
#  'Cali Vea Santa Paula': 'https://domicilios.com/restaurantes/bogota/cali-vea-santa-paula-menu?t=comentarios',
#  'Cali Vea Centro': 'https://domicilios.com/restaurantes/bogota/cali-vea-centro-27679-menu?t=comentarios',
#  'McDonalds AutoNorte': 'https://domicilios.com/restaurantes/bogota/mcdonalds-autonorte-menu?t=comentarios',
#  'KFC Toberin': 'https://domicilios.com/restaurantes/bogota/kfc-toberin-menu?t=comentarios',
#  'PPC Álamos': 'https://domicilios.com/restaurantes/bogota/ppc-alamos-menu?t=comentarios',
#  'Frisby Calle 106': 'https://domicilios.com/restaurantes/bogota/frisby-calle-106-menu?t=comentarios',
#  'La Brasa Roja Plaza Imperial': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-plaza-imperial-menu?t=comentarios',
#  'McDonalds Hayuelos': 'https://domicilios.com/restaurantes/bogota/mcdonalds-hayuelos-menu?t=comentarios',
#  'Kokoriko Restrepo': 'https://domicilios.com/restaurantes/bogota/kokoriko-restrepo-menu?t=comentarios',
#  'Kokoriko Ilarco': 'https://domicilios.com/restaurantes/bogota/kokoriko-ilarco-menu?t=comentarios',
#  'Kokoriko Colina Campestre': 'https://domicilios.com/restaurantes/bogota/kokoriko-colina-campestre-menu?t=comentarios',
#  'KFC Calle 66': 'https://domicilios.com/restaurantes/bogota/kfc-calle-66-menu?t=comentarios',
#  'Cali Vea Santa Helenita': 'https://domicilios.com/restaurantes/bogota/cali-vea-santa-helenita-menu?t=comentarios',
#  'KFC Kennedy': 'https://domicilios.com/restaurantes/bogota/kfc-kennedy-menu?t=comentarios',
#  'Kokoriko Kennedy': 'https://domicilios.com/restaurantes/bogota/kokoriko-kennedy-menu?t=comentarios',
#  'Cali Vea Avenida 1 de Mayo': 'https://domicilios.com/restaurantes/bogota/cali-vea-av-primera-de-mayo-menu?t=comentarios',
#  'KFC Santa Paula': 'https://domicilios.com/restaurantes/bogota/kfc-santa-paula-menu?t=comentarios',
#  'Kokoriko Santa Isabel': 'https://domicilios.com/restaurantes/bogota/kokoriko-santa-isabel-menu?t=comentarios',
#  'Cali Vea Gran Estación': 'https://domicilios.com/restaurantes/bogota/cali-vea-gran-estacion-menu?t=comentarios',
#  'Kokoriko Multidrive': 'https://domicilios.com/restaurantes/bogota/kokoriko-multidrive-menu?t=comentarios',
#  'McDonalds Ciudad Salitre': 'https://domicilios.com/restaurantes/bogota/mcdonalds-ciudad-salitre-menu?t=comentarios',
#  'Wing It! - Chapinero': 'https://domicilios.com/restaurantes/bogota/wing-it-chapinero-menu?t=comentarios',
#  'Cali Vea Chapinero Calle 67': 'https://domicilios.com/restaurantes/bogota/cali-vea-chapinero-calle-67-menu?t=comentarios',
#  "Noah's Green Kitchen - Chapinero": 'https://domicilios.com/restaurantes/bogota/noah-s-green-kitchen-chapinero-menu?t=comentarios',
#  'Sandwich Gourmet Salsa de Ajo Cedritos': 'https://domicilios.com/restaurantes/bogota/sandwich-gourmet-salsa-de-ajo-cedritos-menu?t=comentarios',
#  'La Brasa Roja Fontibon': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-fontibon-menu?t=comentarios',
#  'Randys Hayuelos': 'https://domicilios.com/restaurantes/bogota/randys-hayuelos-menu?t=comentarios',
#  'Perros J&R Esmeralda': 'https://domicilios.com/restaurantes/bogota/perros-j-r-esmeralda-menu?t=comentarios',
#  'KFC Fontibón Centro': 'https://domicilios.com/restaurantes/bogota/kfc-fontibon-centro-menu?t=comentarios',
#  'Cali Vea Country': 'https://domicilios.com/restaurantes/bogota/cali-vea-country-menu?t=comentarios',
#  'KFC Unicentro Bogotá': 'https://domicilios.com/restaurantes/bogota/kfc-unicentro-bogota-menu?t=comentarios',
#  'Cali Vea Plaza Imperial': 'https://domicilios.com/restaurantes/bogota/cali-vea-plaza-imperial-menu?t=comentarios',
#  'Cali Vea Santafé': 'https://domicilios.com/restaurantes/bogota/cali-vea-santafe-menu?t=comentarios',
#  'Cali Vea Fontibon': 'https://domicilios.com/restaurantes/bogota/cali-vea-fontibon-menu?t=comentarios',
#  'Cali Vea Tejar': 'https://domicilios.com/restaurantes/bogota/cali-vea-tejar-menu?t=comentarios',
#  'PPC Primera de Mayo': 'https://domicilios.com/restaurantes/bogota/ppc-primera-de-mayo-menu?t=comentarios',
#  'Cali Vea Palatino': 'https://domicilios.com/restaurantes/bogota/cali-vea-palatino-menu?t=comentarios',
#  'La Brasa Roja Cedritos': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-cedritos-menu?t=comentarios',
#  'Poked - Cedritos': 'https://domicilios.com/restaurantes/bogota/poked-cedritos-menu?t=comentarios',
#  'McDonalds 1 de Mayo': 'https://domicilios.com/restaurantes/bogota/mcdonalds-1-de-mayo-menu?t=comentarios',
#  'Cali Vea Casa Blanca': 'https://domicilios.com/restaurantes/bogota/cali-vea-casa-blanca-menu?t=comentarios',
#  "Noah's Green Kitchen - El Polo": 'https://domicilios.com/restaurantes/bogota/noah-s-green-kitchen-el-polo-menu?t=comentarios',
#  'PPC Normandia': 'https://domicilios.com/restaurantes/bogota/ppc-normandia-menu?t=comentarios',
#  'Presto Av Chile': 'https://domicilios.com/restaurantes/bogota/presto-av-chile-menu?t=comentarios',
#  "Noah's Green Kitchen - Salitre Occidental": 'https://domicilios.com/restaurantes/bogota/noah-s-green-kitchen-salitre-occidental-menu?t=comentarios',
#  'La Brasa Roja Casablanca': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-casablanca-menu?t=comentarios',
#  'Presto Conecta': 'https://domicilios.com/restaurantes/bogota/presto-conecta-menu?t=comentarios',
#  'Cali Vea San Cayetano': 'https://domicilios.com/restaurantes/bogota/cali-vea-san-cayetano-menu?t=comentarios',
#  'Crik  Chapinero': 'https://domicilios.com/restaurantes/bogota/crik-la-hamburguesa-chapinero-menu?t=comentarios',
#  'McDonalds DiverPlaza': 'https://domicilios.com/restaurantes/bogota/mcdonalds-diverplaza-menu?t=comentarios',
#  'Cali Vea Galan': 'https://domicilios.com/restaurantes/bogota/cali-vea-galan-menu?t=comentarios',
#  'Kokoriko UniAbastos': 'https://domicilios.com/restaurantes/bogota/kokoriko-uniabastos-menu?t=comentarios',
#  'Cali Vea Jumbo Hayuelos': 'https://domicilios.com/restaurantes/bogota/cali-vea-jumbo-hayuelos-menu?t=comentarios',
#  'Charlies Roastbeef San Rafael': 'https://domicilios.com/restaurantes/bogota/charlies-roastbeef-san-rafael-menu?t=comentarios',
#  'Cali Vea Metro Sur': 'https://domicilios.com/restaurantes/bogota/cali-vea-alkosto-venecia-menu?t=comentarios',
#  'Kokoriko Palatino': 'https://domicilios.com/restaurantes/bogota/kokoriko-palatino-menu?t=comentarios',
#  'La Brasa Roja Santa Helenita': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-santa-helenita-menu?t=comentarios',
#  'MUY Calle 79': 'https://domicilios.com/restaurantes/bogota/muy-calle-79-menu?t=comentarios',
#  'McDonalds Calle 138': 'https://domicilios.com/restaurantes/bogota/mcdonalds-calle-138-menu?t=comentarios',
#  'La Brasa Roja Lourdes': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-lourdes-menu?t=comentarios',
#  'Kokoriko Feria Expo': 'https://domicilios.com/restaurantes/bogota/kokoriko-feria-expo-menu?t=comentarios',
#  'Frisby Calle 145': 'https://domicilios.com/restaurantes/bogota/frisby-calle-145-menu?t=comentarios',
#  'La Brasa Roja Colina Campestre': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-colina-campestre-menu?t=comentarios',
#  'Kokoriko Calle 71 Al Paso': 'https://domicilios.com/restaurantes/bogota/kokoriko-calle-71-al-paso-menu?t=comentarios',
#  'Cali Vea Tibabuyes': 'https://domicilios.com/restaurantes/bogota/cali-vea-tibabuyes-menu?t=comentarios',
#  'Cali Vea Villas': 'https://domicilios.com/restaurantes/bogota/cali-vea-villas-menu?t=comentarios',
#  'La Brasa Roja Quirigua': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-quirigua-menu?t=comentarios',
#  'Kokoriko Calle 93': 'https://domicilios.com/restaurantes/bogota/kokoriko-calle-93-menu?t=comentarios',
#  'Cali Vea Kennedy': 'https://domicilios.com/restaurantes/bogota/cali-vea-kennedy-menu?t=comentarios',
#  'La Brasa Roja Normandia': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-normandia-menu?t=comentarios',
#  'PPC Ciudad Montes': 'https://domicilios.com/restaurantes/bogota/ppc-ciudad-montes-menu?t=comentarios',
#  'El Carnal Plaza Imperial': 'https://domicilios.com/restaurantes/bogota/el-carnal-plaza-imperial-menu?t=comentarios',
#  'KFC C.C Plaza Central': 'https://domicilios.com/restaurantes/bogota/kfc-c-c-plaza-central-menu?t=comentarios',
#  'La Brasa Roja Santa Isabel': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-santa-isabel-menu?t=comentarios',
#  'Cali Vea Bosa': 'https://domicilios.com/restaurantes/bogota/cali-vea-bosa-menu?t=comentarios',
#  'La Brasa Roja Galán': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-galan-menu?t=comentarios',
#  'La Brasa Roja Bosa': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-bosa-menu?t=comentarios',
#  'McDonalds Chapinero': 'https://domicilios.com/restaurantes/bogota/mcdonalds-chapinero-menu?t=comentarios',
#  'Cali Vea Jumbo Calle 80': 'https://domicilios.com/restaurantes/bogota/cali-vea-jumbo-calle-80-menu?t=comentarios',
#  'Perros J&R Alhambra': 'https://domicilios.com/restaurantes/bogota/perros-j-r-alhambra-menu?t=comentarios',
#  'PPC Quinta Paredes': 'https://domicilios.com/restaurantes/bogota/ppc-cipres-menu?t=comentarios',
#  'Cali Vea  Tunal': 'https://domicilios.com/restaurantes/bogota/cali-vea-tunal-menu?t=comentarios',
#  'Cali Vea Av Chile': 'https://domicilios.com/restaurantes/bogota/cali-vea-av-chile-menu?t=comentarios',
#  'Cali Vea Paloquemao': 'https://domicilios.com/restaurantes/bogota/cali-vea-paloquemao-menu?t=comentarios',
#  'KFC CC Calima': 'https://domicilios.com/restaurantes/bogota/kfc-cc-calima-menu?t=comentarios',
#  'KFC CC Salitre Plaza': 'https://domicilios.com/restaurantes/bogota/kfc-cc-salitre-plaza-menu?t=comentarios',
#  'La Brasa Roja Villas': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-villas-menu?t=comentarios',
#  'Cali Vea C.C. San Rafael': 'https://domicilios.com/restaurantes/bogota/cali-vea-c-c-san-rafael-menu?t=comentarios',
#  'La Brasa Roja Castilla': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-castilla-menu?t=comentarios',
#  'La Brasa Roja Contador': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-contador-menu?t=comentarios',
#  'La Brasa Roja Galerías': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-galerias-menu?t=comentarios',
#  'La Brasa Roja Castellana': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-castellana-menu?t=comentarios',
#  'La Brasa Roja Chapinero Calle 41': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-chapinero-calle-41-menu?t=comentarios',
#  'La Brasa Roja World Trade Center': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-world-trade-center-menu?t=comentarios',
#  'Kokoriko Home Center CLL 170': 'https://domicilios.com/restaurantes/bogota/kokoriko-home-center-cll-170-menu?t=comentarios',
#  'La Brasa Roja Chapinero Calle 67': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-chapinero-calle-67-menu?t=comentarios',
#  'La Brasa Roja Cipres': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-cipres-menu?t=comentarios',
#  'Paisa Wings 150': 'https://domicilios.com/restaurantes/bogota/paisa-wings-menu?t=comentarios',
#  'Perros J&R Plaza de las Américas': 'https://domicilios.com/restaurantes/bogota/perros-j-r-plaza-de-las-americas-menu?t=comentarios',
#  'KFC Plaza de las Americas': 'https://domicilios.com/restaurantes/bogota/kfc-plaza-de-las-americas-menu?t=comentarios',
#  'La Brasa Roja Av Chile': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-av-chile-menu?t=comentarios',
#  'Cali Vea Alkosto 170': 'https://domicilios.com/restaurantes/bogota/cali-vea-alkosto-170-menu?t=comentarios',
#  'La Brasa Roja Kennedy': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-kennedy-menu?t=comentarios',
#  'Cali Vea Homecenter Alquería': 'https://domicilios.com/restaurantes/bogota/cali-vea-homecenter-alqueria-menu?t=comentarios',
#  'La Brasa Roja Tibabuyes': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-tibabuyes-menu?t=comentarios',
#  'La Brasa Roja Auto Norte': 'https://domicilios.com/restaurantes/bogota/la-brasa-roja-auto-norte-menu?t=comentarios',
#  'Cali Vea Metrópolis': 'https://domicilios.com/restaurantes/bogota/cali-vea-metropolis-menu?t=comentarios',
# ...
#  'La Ponderosa - Gran Estación': 'https://domicilios.com/restaurantes/bogota/la-ponderosa-gran-estacion-menu?t=comentarios',
#  'Holy Cheese': 'https://domicilios.com/restaurantes/bogota/holy-cheese-menu?t=comentarios',
#  'Forte Pizza': 'https://domicilios.com/restaurantes/bogota/forte-pizza-menu?t=comentarios',
#  'Sandwich Qbano Plaza Belaire.': 'https://domicilios.com/restaurantes/bogota/sandwich-qbano-plaza-belaire-29310-menu?t=comentarios',
#  'El Arepazo Cl 52': 'https://domicilios.com/restaurantes/bogota/el-arepazo-cl-52-menu?t=comentarios',
#  "Waffles n' Coffee": 'https://domicilios.com/restaurantes/bogota/waffles-n-coffee-menu?t=comentarios',
#  'Alitas Colombianas Andino': 'https://domicilios.com/restaurantes/bogota/alitas-colombianas-andino-menu?t=comentarios',
#  'Don Jediondo Sopitas y Parrilla Iserra 100': 'https://domicilios.com/restaurantes/bogota/don-jediondo-sopitas-y-parrilla-iserra-100-menu?t=comentarios',
#  'Mr. Eats Calle 161': 'https://domicilios.com/restaurantes/bogota/mr-eats-calle-161-menu?t=comentarios',
#  'Pizza Hut Santa Ana': 'https://domicilios.com/restaurantes/bogota/pizza-hut-santa-ana-menu?t=comentarios',
#  'Arroces y Algo Más! - Engativa': 'https://domicilios.com/restaurantes/bogota/arroces-y-algo-mas-engativa-menu?t=comentarios',
#  'Capital Wings Bogotá': 'https://domicilios.com/restaurantes/bogota/capital-wings-bogota-menu?t=comentarios',
#  'Mr. Eats Caobos': 'https://domicilios.com/restaurantes/bogota/mr-eats-caobos-menu?t=comentarios',
#  'Comidas Rápidas Fierros': 'https://domicilios.com/restaurantes/bogota/comidas-rapidas-fierros-menu?t=comentarios',
#  'Mr. Eats Chapinero': 'https://domicilios.com/restaurantes/bogota/mr-eats-chapinero-menu?t=comentarios',
#  'Gringo Burgers': 'https://domicilios.com/restaurantes/bogota/gringo-burgers-menu?t=comentarios',
#  'Bogotá Food Company Centro': 'https://domicilios.com/restaurantes/bogota/bogota-food-company-centro-menu?t=comentarios',
#  'Sumo Sushi Usaquen': 'https://domicilios.com/restaurantes/bogota/sumo-sushi-usaquen-menu?t=comentarios',
#  'Arroz y Pasta al Wok Centro': 'https://domicilios.com/restaurantes/bogota/arroz-y-pasta-al-wok-centro-menu?t=comentarios',
#  'Mr Sándwich Bogotá': 'https://domicilios.com/restaurantes/bogota/mr-sandwich-bogota-menu?t=comentarios',
#  'Hamburguesas El Corral Bulevar Niza': 'https://domicilios.com/restaurantes/bogota/hamburguesas-el-corral-bulevar-niza-menu?t=comentarios',
#  'Pizzaiolo Bogotá': 'https://domicilios.com/restaurantes/bogota/pizzaiolo-bogota-menu?t=comentarios',
#  'Kyoto Oriental Salitre': 'https://domicilios.com/restaurantes/bogota/kyoto-oriental-salitre-menu?t=comentarios',
#  'Parrilla a la Lata Fontibón': 'https://domicilios.com/restaurantes/bogota/parrilla-a-la-lata-fontibon-menu?t=comentarios',
#  'Veggie Go Floresta': 'https://domicilios.com/restaurantes/bogota/veggie-go-floresta-menu?t=comentarios',
#  'La Chispa Roja Álamos': 'https://domicilios.com/restaurantes/bogota/la-chispa-roja-alamos-menu?t=comentarios',
#  'La Ponderosa - Santa Bárbara': 'https://domicilios.com/restaurantes/bogota/la-ponderosa-santa-barbara-menu?t=comentarios',
#  'Mi Calle': 'https://domicilios.com/restaurantes/bogota/mi-calle-menu?t=comentarios',
#  'Baquero´s Burger': 'https://domicilios.com/restaurantes/bogota/baquero%C2%B4s-burger-menu?t=comentarios',
#  'Pizza Hut Zona 41': 'https://domicilios.com/restaurantes/bogota/pizza-hut-zona-41-menu?t=comentarios',
#  'Gabo´s Burger': 'https://domicilios.com/restaurantes/bogota/gabo%C2%B4s-burger-menu?t=comentarios',
#  'Tipicas Empanadas Multidrive': 'https://domicilios.com/restaurantes/bogota/tipicas-empanadas-multidrive-menu?t=comentarios',
#  'Panne Cook and Crepes': 'https://domicilios.com/restaurantes/bogota/panne-cook-and-crepes-menu?t=comentarios',
#  'Oriental Food': 'https://domicilios.com/restaurantes/bogota/oriental-food-menu?t=comentarios',
#  'SBA - Super Broaster Americano Chapinero': 'https://domicilios.com/restaurantes/bogota/sba-super-broaster-americano-chapinero-menu?t=comentarios',
#  'Bogota Food Company': 'https://domicilios.com/restaurantes/bogota/bogota-food-company-menu?t=comentarios',
#  'Cocheros El Lago': 'https://domicilios.com/restaurantes/bogota/cocheros-el-lago-menu?t=comentarios',
#  'Bogota Food Company 89': 'https://domicilios.com/restaurantes/bogota/bogota-food-company-89-menu?t=comentarios',
#  'Andrés Exprés - Cafam Floresta': 'https://domicilios.com/restaurantes/bogota/andres-expres-cafam-floresta-menu?t=comentarios',
#  'Food Master': 'https://domicilios.com/restaurantes/bogota/food-master-menu?t=comentarios',
#  'MiPaella.co': 'https://domicilios.com/restaurantes/bogota/mipaella-co-menu?t=comentarios',
#  'Club de la Pizza Bogotá': 'https://domicilios.com/restaurantes/bogota/club-de-la-pizza-bogota-menu?t=comentarios',
#  'Hamburguesas Standar Burguer Logística': 'https://domicilios.com/restaurantes/bogota/hamburguesas-standar-burguer-logistica-menu?t=comentarios',
#  'Wings Delivery': 'https://domicilios.com/restaurantes/bogota/wings-delivery-menu?t=comentarios',
#  'Carnes la Zarza': 'https://domicilios.com/restaurantes/bogota/carnes-la-zarza-menu?t=comentarios',
#  'Origen Burgers and Fries Multiplaza': 'https://domicilios.com/restaurantes/bogota/origen-burgers-and-fries-multiplaza-menu?t=comentarios',
#  'Alitas Colombianas Castellana': 'https://domicilios.com/restaurantes/bogota/alitas-colombianas-calle-95-menu?t=comentarios',
#  'Pizza Inn Norte': 'https://domicilios.com/restaurantes/bogota/pizza-inn-norte-menu?t=comentarios',
#  'La Choneria': 'https://domicilios.com/restaurantes/bogota/la-choneria-menu?t=comentarios',
#  'Fillet Station 74': 'https://domicilios.com/restaurantes/bogota/fillet-station-72-menu?t=comentarios',
#  'Di´Salnut': 'https://domicilios.com/restaurantes/bogota/disalnut-menu?t=comentarios',
#  'Santo Pollo': 'https://domicilios.com/restaurantes/bogota/santo-pollo-menu?t=comentarios',
#  'Arroz y Pasta al Wok Centro Calle 34': 'https://domicilios.com/restaurantes/bogota/arroz-y-pasta-al-wok-marketplace-centro-menu?t=comentarios',
#  'Las Barbas de Choclo': 'https://domicilios.com/restaurantes/bogota/las-barbas-de-choclo-menu?t=comentarios',
#  'Sándwich Qbano Av. Restrepo': 'https://domicilios.com/restaurantes/bogota/sandwich-qbano-av-restrepo-menu?t=comentarios',
#  'Konfood Santa Isabel': 'https://domicilios.com/restaurantes/bogota/konfood-santa-isabel-menu?t=comentarios',
#  'Frisby 140': 'https://domicilios.com/restaurantes/bogota/frisby-140-menu?t=comentarios',
#  'Yogen Fruz Paseo San Rafael': 'https://domicilios.com/restaurantes/bogota/yogen-fruz-paseo-san-rafael-menu?t=comentarios',
#  'Don Jediondo Sopitas y Parrilla Unicentro': 'https://domicilios.com/restaurantes/bogota/don-jediondo-sopitas-y-parrilla-unicentro-menu?t=comentarios',
#  'Mero Taco Comida Rápida Mexicana Chapinero': 'https://domicilios.com/restaurantes/bogota/mero-taco-comida-rapida-mexicana-chapinero-menu?t=comentarios',
#  'La Hamburgueseria Emaus': 'https://domicilios.com/restaurantes/bogota/la-hamburgueseria-emaus-menu?t=comentarios',
#  'Toy Wok': 'https://domicilios.com/restaurantes/bogota/toy-wok-menu?t=comentarios',
#  'Viva la Pizza C.C. Calima': 'https://domicilios.com/restaurantes/bogota/viva-la-pizza-c-c-calima-menu?t=comentarios',
#  'Entre Pisco y Nazca Gastronomia Peruana': 'https://domicilios.com/restaurantes/bogota/entre-pisco-y-nazca-gastronomia-peruana-menu?t=comentarios',
#  'Jenos Pizza Diver Plaza': 'https://domicilios.com/restaurantes/bogota/jenos-pizza-diver-plaza-menu?t=comentarios',
#  'Don Jediondo Sopitas y Parrilla C.C San Martin': 'https://domicilios.com/restaurantes/bogota/don-jediondo-sopitas-y-parrilla-c-c-san-martin-menu?t=comentarios',
#  'Gula Gourmet.': 'https://domicilios.com/restaurantes/bogota/gula-gourmet-bogota-menu?t=comentarios',
#  'Sushi Deli El Prado': 'https://domicilios.com/restaurantes/bogota/sushi-deli-el-prado-menu?t=comentarios',
#  "Sushi Roll's - Norte": 'https://domicilios.com/restaurantes/bogota/sushi-rolls-villa-elisa-menu?t=comentarios',
#  'Castillo Chino': 'https://domicilios.com/restaurantes/bogota/castillo-chino-menu?t=comentarios',
#  'La Parrilla la Original - Unicentro': 'https://domicilios.com/restaurantes/bogota/la-parrilla-la-original-unicentro-menu?t=comentarios',
#  'Minos Gourmet Delivery': 'https://domicilios.com/restaurantes/bogota/minos-gourmet-delivery-menu?t=comentarios',
#  'Surtidora de aves la 22 Engativá': 'https://domicilios.com/restaurantes/bogota/surtidora-de-aves-la-22-engativa-menu?t=comentarios',
#  'Mega Hot Modelia': 'https://domicilios.com/restaurantes/bogota/mega-hot-modelia-menu?t=comentarios',
#  'Arepas 100% Maíz': 'https://domicilios.com/restaurantes/bogota/arepas-100-maiz-menu?t=comentarios',
#  'Empanadas La Casona 127': 'https://domicilios.com/restaurantes/bogota/empanadas-la-casona-127-menu?t=comentarios',
#  'Mr Jack Colina': 'https://domicilios.com/restaurantes/bogota/mr-jack-colina-menu?t=comentarios',
#  'Wok to Walk Rosales': 'https://domicilios.com/restaurantes/bogota/wok-to-walk-rosales-menu?t=comentarios',
#  'Burger Bike': 'https://domicilios.com/restaurantes/bogota/burger-bike-menu?t=comentarios',
#  'Empanadas La Casona Mall 138': 'https://domicilios.com/restaurantes/bogota/empanadas-la-casona-mall-138-menu?t=comentarios',
#  'Capitán Budha Wok Style': 'https://domicilios.com/restaurantes/bogota/capitan-budha-wok-style-menu?t=comentarios',
#  'Mr Burger Bogotá': 'https://domicilios.com/restaurantes/bogota/mr-burger-bogota-menu?t=comentarios',
#  'Pig Mama Food': 'https://domicilios.com/restaurantes/bogota/pig-mama-food-menu?t=comentarios',
#  'Éxito del Sabor': 'https://domicilios.com/restaurantes/bogota/exito-del-sabor-menu?t=comentarios',
#  'Inbite Casablanca': 'https://domicilios.com/restaurantes/bogota/inbite-casablanca-menu?t=comentarios',
#  'Luigi´s Pizza Gourmet': 'https://domicilios.com/restaurantes/bogota/luigis-pizza-gourmet-menu?t=comentarios',
#  'Chancho Rico, Fritanga y Picadas Carrera 45': 'https://domicilios.com/restaurantes/bogota/chancho-rico-fritanga-y-picadas-logistica-menu?t=comentarios',
#  'Hot Sándwich': 'https://domicilios.com/restaurantes/bogota/hot-sandwich-menu?t=comentarios',
#  'Casterolli Cocina Italiana - Techo': 'https://domicilios.com/restaurantes/bogota/casterolli-cocina-italiana-techo-menu?t=comentarios',
#  'Century Broaster Chicken Restrepo': 'https://domicilios.com/restaurantes/bogota/century-broaster-chicken-restrepo-menu?t=comentarios',
#  'Happy Salad Prado': 'https://domicilios.com/restaurantes/bogota/happy-salad-prado-menu?t=comentarios',
#  'Pizza Imperial': 'https://domicilios.com/restaurantes/bogota/pizza-imperial-menu?t=comentarios',
#  '11:11 Crepes': 'https://domicilios.com/restaurantes/bogota/1111-crepes-menu?t=comentarios',
#  'Konfood Quirigua': 'https://domicilios.com/restaurantes/bogota/konfood-quirigua-menu?t=comentarios',
#  'Cosechas Calle 73': 'https://domicilios.com/restaurantes/bogota/cosechas-calle-73-menu?t=comentarios',
#  'Konfood Avenida 1 de Mayo': 'https://domicilios.com/restaurantes/bogota/konfood-avenida-primero-de-mayo-menu?t=comentarios',
#  'La Hamburgueseria Soledad': 'https://domicilios.com/restaurantes/bogota/la-hamburgueseria-soledad-menu?t=comentarios',
#  'Konfood Centro': 'https://domicilios.com/restaurantes/bogota/konfood-centro-menu?t=comentarios',
#  'La Hamburgueseria Quinta Paredes': 'https://domicilios.com/restaurantes/bogota/la-hamburgueseria-quinta-paredes-menu?t=comentarios',
#  'Pizza Gourmet 66-69': 'https://domicilios.com/restaurantes/bogota/pizza-gourmet-66-69-menu?t=comentarios',
#  'Alitas y Papitas': 'https://domicilios.com/restaurantes/bogota/alitas-y-papitas-menu?t=comentarios',
#  'Deli Repostería Salitre': 'https://domicilios.com/restaurantes/bogota/deli-reposteria-salitre-menu?t=comentarios',
#  'Inbite Castilla': 'https://domicilios.com/restaurantes/bogota/inbite-castilla-menu?t=comentarios',
#  "Maxx Rock'n Roll Burger": 'https://domicilios.com/restaurantes/bogota/maxx-rock-n-roll-menu?t=comentarios',
#  'Restaurante Chino Shen Yang': 'https://domicilios.com/restaurantes/bogota/restaurante-chino-shen-yang-menu?t=comentarios',
#  'Maki & Grill': 'https://domicilios.com/restaurantes/bogota/maki-grill-menu?t=comentarios',
#  'Burger 5': 'https://domicilios.com/restaurantes/bogota/burger-5-menu?t=comentarios',
#  'Inbite Bosa': 'https://domicilios.com/restaurantes/bogota/inbite-bosa-menu?t=comentarios',
#  "The Shot's Bar Pizzería": 'https://domicilios.com/restaurantes/bogota/the-shots-bar-pizzeria-menu?t=comentarios',
#  'Konfood Casa Blanca': 'https://domicilios.com/restaurantes/bogota/konfood-casa-blanca-menu?t=comentarios',
#  'Century Broaster Chicken Calima': 'https://domicilios.com/restaurantes/bogota/century-broaster-chicken-calima-menu?t=comentarios',
#  'Konfood Galan': 'https://domicilios.com/restaurantes/bogota/konfood-galan-menu?t=comentarios',
#  'Konfood Garces Navas': 'https://domicilios.com/restaurantes/bogota/konfood-garces-navas-menu?t=comentarios',
#  'Palo Bonito': 'https://domicilios.com/restaurantes/bogota/palo-bonito-menu?t=comentarios',
#  'Konfood Ilarco': 'https://domicilios.com/restaurantes/bogota/konfood-ilarco-menu?t=comentarios',
#  'La Hamburgueseria Usaquén': 'https://domicilios.com/restaurantes/bogota/la-hamburgueseria-usaquen-menu?t=comentarios',
#  'Konfood Normandia': 'https://domicilios.com/restaurantes/bogota/konfood-normandia-menu?t=comentarios',
#  'Sándwich Qbano Calle 90': 'https://domicilios.com/restaurantes/bogota/sandwich-qbano-cll90-menu?t=comentarios',
#  'Habemus Pasta': 'https://domicilios.com/restaurantes/bogota/habemus-pasta-menu?t=comentarios',
#  'Konfood Tejar': 'https://domicilios.com/restaurantes/bogota/konfood-tejar-menu?t=comentarios',
#  'Xin Jiang II': 'https://domicilios.com/restaurantes/bogota/xin-jiang-ii-menu?t=comentarios',
#  'La Chancha': 'https://domicilios.com/restaurantes/bogota/la-chancha-menu?t=comentarios',
#  '11:11 Crepes Log': None,
#  '123 La Parrilla Otra Vez': None,
#  '1937 Gastro Pub': None,
#  'A 2 Manos': None,
#  'American Pizza Bogotá': None,
#  'Apetitosos': None,
#  'Ararat Frescura Y Sabor': None,
#  'Arepa Gourmet': None,
#  'Arepana': None,
#  'Arroz Paisa El Original Caldense Al Wok 170': None,
#  'Arroz Paisa Fontibon': None,
#  'Arroz Paisa Normandia': None,
#  'Ay Maria': None,
#  'Baloo Calle 77': None,
#  'Barichara Parrilla Santandereana Express Bogotá': None,
#  'Bendita': None,
#  'Bendito Sushi Plaza 80': None,
#  'Bife Parrilla Bogotá': None,
#  'Big Tasty Parrilla': None,
#  "Bob's Colina": None,
#  'Bogotown Restaurante': None,
#  'Bugs Pizza': None,
#  'Bukra Burger': None,
#  'Burger Company Cr 112': None,
#  'Burguers,Max': None,
#  'Camoi Rice And Wings': None,
#  'Capadocia': None,
#  'Caracol Rojo Portal 80': None,
#  'Casterly Rock Burguer': None,
#  'Cevichería 66 Cra 4': None,
#  'Ciros Pasteles': None,
#  'Coconuts Frutería y Café': None,
#  'Crep Arepas': None,
#  'De Maíz Mahíz Sabor Ancestral': None,
#  'El Barril Suba': None,
#  'El Boleo Food Truck': None,
#  'El Butaco': None,
#  'El Marrano Volador Barrios Unidos': None,
#  'El Planchón Colina': None,
#  'Empanadas Donde Toñito': None,
#  'Eshcol Fusión Asia': None,
#  'Flow Patata': None,
#  'Fruttidorados de la 167': None,
#  'Full Mazorca': None,
#  'Galgo': None,
#  'Gardel': None,
#  'Hamburguesas donde el Gordo': None,
#  'Heladería & Café': None,
#  'Ipizza Chapinero': None,
#  'Ismay Burger': None,
#  'Karen´s Burger': None,
#  'Kinsei Sushi Calle 127': None,
#  'Kirisuto Comida Fusión Oriental': None,
#  'La Arepería Cedritos': None,
#  'La Gloria Food': None,
#  'La Perrada de Apolo Modelia': None,
#  'Las Delicias de Alberto': None,
#  'Lasagna Lovers - Bogotá': None,
#  'Le Crepe Bogotá': None,
#  'Lokal Pasta': None,
#  'MUY Unicentro': None,
#  'MUY WTC': None,
#  'Mac Rooster': None,
#  'Magos Del Sabor': None,
#  'Magos Del Sabor Bogotá': None,
#  'Magos del Sabor Carrera 62': None,
#  'Marush pizza': None,
#  'Mazork BBQ': None,
#  'Memos': None,
#  'Mereng Cream': None,
#  'MexiWing Food': None,
#  'Mexican Fast Food': None,
#  'Mr Chido': None,
#  'Nativos  Centro Comercial Metrópolis': None,
#  'Nativos Porto Alegre': None,
#  'Nido Plaza imperial': None,
#  'Oriza Arroces y Parrilla': None,
#  'Paisa Wings 117': None,
#  ...}
